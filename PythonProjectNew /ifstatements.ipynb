# %% [markdown]
# 5-1. Conditional Tests: Write a series of conditional tests. Print a statement
# describing each test and your prediction for the results of each test. Your code
# should look something like this:
# car = 'subaru'
# print("Is car == 'subaru'? I predict True.")
# print(car == 'subaru')
# print("\nIs car == 'audi'? I predict False.")
# print(car == 'audi')

# %% [markdown]
# *Look closely at your results, and make sure you understand why each line
# evaluates to True or False.
# *Create at least 10 tests. Have at least 5 tests evaluate to True and another
# 5 tests evaluate to False.

# %%
car = 'subaru'
print("Is car == 'subaru'? I predict True.")
print(car == 'subaru')
print("")
# Out:
# Is car == 'subaru'? I predict True.
# True

# %%
car = 'subaru'
print("Is car == 'audi'? I predict False.")
print(car == 'audi')
print("")
# Out:
# Is car == 'audi'? I predict False.
# False

# %%
car = 'subaru'
print("Is car != 'bmw'? I predict True.")
print(car != 'bmw')
print("")
# Out:
# Is car != 'bmw'? I predict True.
# True

# %%
car = 'subaru'
print("Is car == 'Subaru'? I predict False. (Case sensitive)")
print(car == 'Subaru')
print("")
# Out:
# Is car == 'Subaru'? I predict False. (Case sensitive)
# False

# %%
age = 25
print("Is age >= 18? I predict True.")
print(age >= 18)
print("")
# Out:
# Is age >= 18? I predict True.
# True

# %%
age = 25
print("Is age < 21? I predict False.")
print(age < 21)
print("")
# Out:
# Is age < 21? I predict False.
# False

# %%
is_student = True
print("Is is_student == True? I predict True.")
print(is_student == True)
print("")
# Out:
# Is is_student == True? I predict True.
# True

# %%
is_student = True
print("Is is_student == False? I predict False.")
print(is_student == False)
print("")
# Out:
# Is is_student == False? I predict False.
# False

# %%
favorite_color = 'blue'
print("Is favorite_color == 'blue'? I predict True.")
print(favorite_color == 'blue')
print("")
# Out:
# Is favorite_color == 'blue'? I predict True.
# True

# %%
favorite_color = 'blue'
print("Is favorite_color == 'red'? I predict False.")
print(favorite_color == 'red')
print("")
# Out:
# Is favorite_color == 'red'? I predict False.
# False

# %% [markdown]
# 5-2. More Conditional Tests: You don’t have to limit the number of tests you
# create to 10. If you want to try more comparisons, write more tests and add
# them to conditional_tests.py. Have at least one True and one False result for
# each of the following:
# •	 Tests for equality and inequality with strings
# •	 Tests using the lower() function
# •	 Numerical tests involving equality and inequality, greater than and
# less than, greater than or equal to, and less than or equal to
# •	 Tests using the and keyword and the or keyword
# •	 Test whether an item is in a list
# •	 Test whether an item is not in a list

# %%
car = 'subaru'
print("1. String Equality and Inequality:")
print("Is car == 'subaru'? I predict True.")
print(car == 'subaru')
# Out:
# 1. String Equality and Inequality:
# Is car == 'subaru'? I predict True.
# True

# %%
car = 'subaru'
print("\nIs car == 'audi'? I predict False.")
print(car == 'audi')
# Out:
# Is car == 'audi'? I predict False.
# False

# %%
car = 'subaru'
print("\nIs car != 'honda'? I predict True.")
print(car != 'honda')
# Out:
# Is car != 'honda'? I predict True.
# True

# %%
car = 'subaru'
print("\n2. Tests using lower() function:")
print("Is car.lower() == 'subaru'? I predict True.")
print(car.lower() == 'subaru')
# Out:
# 2. Tests using lower() function:
# Is car.lower() == 'subaru'? I predict True.
# True

# %%
car = 'subaru'
print("\nIs car == 'SUBARU'? I predict False.")
print(car == 'SUBARU')
# Out:
# Is car == 'SUBARU'? I predict False.
# False

# %%
car = 'subaru'
print("\nIs car.lower() == 'SUBARU'? I predict False.")
print(car.lower() == 'SUBARU')
# Out:
# Is car.lower() == 'SUBARU'? I predict False.
# False

# %%
age = 25
print("\n3. Numerical Tests:")
print("Is age == 25? I predict True.")
print(age == 25)
# Out:
# 3. Numerical Tests:
# Is age == 25? I predict True.
# True

# %%
age = 25
print("\nIs age != 30? I predict True.")
print(age != 30)

print("\nIs age > 18? I predict True.")
print(age > 18)

print("\nIs age < 21? I predict False.")
print(age < 21)

print("\nIs age >= 25? I predict True.")
print(age >= 25)

print("\nIs age <= 20? I predict False.")
print(age <= 20)
# Out:
# Is age != 30? I predict True.
# True
#
# Is age > 18? I predict True.
# True
#
# Is age < 21? I predict False.
# False
#
# Is age >= 25? I predict True.
# True
#
# Is age <= 20? I predict False.
# False

# %%
age = 25
print(age >= 18 and age <= 30)
# Out:
# True

# %%
age = 25
print(age > 30 or car == 'subaru')
# Out:
# True

# %%
age = 25
print(age < 18 and car == 'subaru')
# Out:
# False

# %%
favorite_fruits = ['mango', 'banana', 'apple', 'orange']
print('banana' in favorite_fruits)
# Out:
# True

# %%
favorite_fruits = ['mango', 'banana', 'apple', 'orange']
print('grapes' in favorite_fruits)
# Out:
# False

# %%
favorite_fruits = ['mango', 'banana', 'apple', 'orange']
print('watermelon' not in favorite_fruits)
# Out:
# True

# %%
favorite_fruits = ['mango', 'banana', 'apple', 'orange']
print('apple' not in favorite_fruits)
# Out:
# False

# %% [markdown]
# 5-3. Alien Colors #1: Imagine an alien was just shot down in a game. Create a
# variable called alien_color and assign it a value of 'green', 'yellow', or 'red'.
# •	 Write an if statement to test whether the alien’s color is green. If it is, print
# a message that the player just earned 5 points.
# •	 Write one version of this program that passes the if test and another that
# fails. (The version that fails will have no output.)

# %%
alien_color = 'green'
if alien_color == 'green':
    print("You just earned 5 points!")
# Out:
# You just earned 5 points!

# %%
alien_color = 'yellow'   # or 'red'
if alien_color == 'green':
    print("You just earned 5 points!")

# %% [markdown]
# 5-4. Alien Colors #2: Choose a color for an alien as you did in Exercise 5-3, and
# write an if-else chain.
# •	 If the alien’s color is green, print a statement that the player just earned
# 5 points for shooting the alien.
# •	 If the alien’s color isn’t green, print a statement that the player just earned
# 10 points.
# •	 Write one version of this program that runs the if block and another that
# runs the else block

# %%
alien_color = 'green'
if alien_color == 'green':
    print("You just earned 5 points for shooting the alien!")
else:
    print("You just earned 10 points!")
# Out:
# You just earned 5 points for shooting the alien!

# %%
alien_color = 'yellow'     # Try 'red' or any other color
if alien_color == 'green':
    print("You just earned 5 points for shooting the alien!")
else:
    print("You just earned 10 points!")
# Out:
# You just earned 10 points!

# %% [markdown]
# 5-5. Alien Colors #3: Turn your If-else chain from Exercise 5-4 into an if-ellf-else chain.
# • If the alien is green, print a message that the player earned 5 points.
# • If the alien is yellow, print a message that the player earned 10 points.
# • If the alien is red, print a message that the player earned 15 points.
# • Write three versions of this program, making sure each message is printed for the appropriate color alien.

# %%
alien_color = 'green'
if alien_color == 'green':
    print("You just earned 5 points!")
elif alien_color == 'yellow':
    print("You just earned 10 points!")
elif alien_color == 'red':
    print("You just earned 15 points!")
else:
    print("Unknown alien color.")
# Out:
# You just earned 5 points!

# %%
alien_color = 'yellow'
if alien_color == 'green':
    print("You just earned 5 points!")
elif alien_color == 'yellow':
    print("You just earned 10 points!")
elif alien_color == 'red':
    print("You just earned 15 points!")
else:
    print("Unknown alien color.")
# Out:
# You just earned 10 points!

# %%
alien_color = 'red'
if alien_color == 'green':
    print("You just earned 5 points!")
elif alien_color == 'yellow':
    print("You just earned 10 points!")
elif alien_color == 'red':
    print("You just earned 15 points!")
else:
    print("Unknown alien color.")
# Out:
# You just earned 15 points!

# %% [markdown]
# 5-6. Stages of Life: Write an If-elif-else chain that determines a person's stage of life. Set a value for the variable age, and then:
# • Ifthe person is less than 2 years old, print a message that the person is a baby.
# • If the person is at least 2 years old but less than 4, print a message that the person is a toddler.
# • If the person is at least 4 years old but less than 13, print a message that the person is a kid.
# • If the person is at least 13 years old but less than 20, print a message that the person is a teenager.
# • If the person is at least 20 years old but less than 65, print a message that the person is an adult.
# • If the person is age 65 or older, print a message that the person is an older.

# %%
ages = [1, 3, 8, 15, 25, 45, 70]
for age in ages:
    print(f"Age = {age}: ", end="")
    
    if age < 2:
        print("The person is a baby.")
    elif age < 4:
        print("The person is a toddler.")
    elif age < 13:
        print("The person is a kid.")
    elif age < 20:
        print("The person is a teenager.")
    elif age < 65:
        print("The person is an adult.")
    else:
        print("The person is an older person.")
# Out:
# Age = 1: The person is a baby.
# Age = 3: The person is a toddler.
# Age = 8: The person is a kid.
# Age = 15: The person is a teenager.
# Age = 25: The person is an adult.
# Age = 45: The person is an adult.
# Age = 70: The person is an older person.

# %% [markdown]
# 5-7. Favorite Fruit: Make a list of your favorite fruits, and then write a series of independent if statements that check for certain fruits in your list.
# • Make a list of your three favorite fruits and call il favorite_fruits.
# Write five if statements. Each should check whether a certain kind of fruit is in your list. If the fruit is in your list, the if block should print a statement, such as You really like bananas!

# %%
favorite_fruits = ['mango', 'banana', 'strawberry']

if 'mango' in favorite_fruits:
    print("I really like mangoes!")

if 'banana' in favorite_fruits:
    print("I really like bananas!")

if 'strawberry' in favorite_fruits:
    print("I really like strawberries!")

if 'apple' in favorite_fruits:
    print("I really like apples!")

if 'pineapple' in favorite_fruits:
    print("I really like pineapples!")
# Out:
# I really like mangoes!
# I really like bananas!
# I really like strawberries!

# %% [markdown]
# 5-8. Hello Admin: Make a list of five or more usernames, including the name
# "admin'. Imagine you are writing code that will print a greeting to each user after they log in to a website. Loop through the list, and print a greeting to each user:
# • If the username is 'admin', print a special greeting, such as Hello admin,
# would you like to see a status report?
# • Otherwise, print a generic greeting, such as Hello Eric, thank you for log-
# ging in again.

# %%
usernames = ['admin', 'eric', 'sarah', 'david', 'maria', 'john']
for username in usernames:
    if username == 'admin':
        print("Hello admin, would you like to see a status report?")
    else:
        print(f"Hello {username.title()}, thank you for logging in again.")
# Out:
# Hello admin, would you like to see a status report?
# Hello Eric, thank you for logging in again.
# Hello Sarah, thank you for logging in again.
# Hello David, thank you for logging in again.
# Hello Maria, thank you for logging in again.
# Hello John, thank you for logging in again.

# %% [markdown]
# 5-9. No Users: Add an if test to hello_admin.py to make sure the list of users is not empty.
# • If the list is empty, print the message We need to find some users!
# • Remove all of the usernames from your list, and make sure the correct message is printed.

# %%
usernames = ['admin', 'eric', 'sarah', 'david', 'maria']

if usernames:
    for username in usernames:
        if username == 'admin':
            print("Hello admin, would you like to see a status report?")
        else:
            print(f"Hello {username.title()}, thank you for logging in again.")
else:
    print("We need to find some users!")
# Out:
# Hello admin, would you like to see a status report?
# Hello Eric, thank you for logging in again.
# Hello Sarah, thank you for logging in again.
# Hello David, thank you for logging in again.
# Hello Maria, thank you for logging in again.

# %%
usernames = []

if usernames:
    for username in usernames:
        if username == 'admin':
            print("Hello admin, would you like to see a status report?")
        else:
            print(f"Hello {username.title()}, thank you for logging in again.")
else:
    print("We need to find some users!")
# Out:
# We need to find some users!

# %% [markdown]
# 5-10. Checking Usernames: Do the following to create a program that simulates
# how websites ensure that everyone has a unique username.
# • Make a list of five or more usernames called current_users.
# • Make another list of five usernames called new users. Make sure one or two of the new usernames are also in the current_users list.
# • Loop through the new_users list to see if each new username has already
# been used. If it has, print a message that the person will need to enter a new username. If a username has not been used, print a message saying that the userame is available.
# • Make sure your comparison is case insensitive. If "John' has been used,
# "JOHN" should not be accepted.

# %%
current_users = ['admin', 'eric', 'sarah', 'david', 'maria', 'john']
new_users = ['Eric', 'lisa', 'JOHN', 'michael', 'SARAH']

current_users_lower = [user.lower() for user in current_users]
for new_user in new_users:
    if new_user.lower() in current_users_lower:
        print(f"Username '{new_user}' is already taken. Please enter a new username.")
    else:
        print(f"Username '{new_user}' is available.")
# Out:
# Username 'Eric' is already taken. Please enter a new username.
# Username 'lisa' is available.
# Username 'JOHN' is already taken. Please enter a new username.
# Username 'michael' is available.
# Username 'SARAH' is already taken. Please enter a new username.

# %% [markdown]
# 5-11. Ordinal Numbers: Ordinal numbers indicate their position in a list, such as Ist or 2nd. Most ordinal numbers end in th, except 1, 2, and 3.
# • Store the numbers 1 through 9 in a list.
# • Loop through the list.
# • Use an if-elif-else chain inside the loop to print the proper ordinal end-
# ing for each number. Your output should read "ist 2nd 3xd 4th 5th 6th
# 7th Sth 9th", and each result should be on a separate line.

# %%
numbers = list(range(1, 10))

for number in numbers:
    if number == 1:
        ordinal = "1st"
    elif number == 2:
        ordinal = "2nd"
    elif number == 3:
        ordinal = "3rd"
    else:
        ordinal = f"{number}th"
    print(ordinal)
# Out:
# 1st
# 2nd
# 3rd
# 4th
# 5th
# 6th
# 7th
# 8th
# 9th

# %% [markdown]
# 5-12. Styling if statements: Review the programs you wrote in this chapter, and
# make sure you styled your conditional tests appropriately

# %% [markdown]
# this is from 5-5

# %%
alien_color = 'green'

if alien_color == 'green':
    print("You just earned 5 points!")
elif alien_color == 'yellow':
    print("You just earned 10 points!")
elif alien_color == 'red':
    print("You just earned 15 points!")
else:
    print("Unknown alien color.")
# Out:
# You just earned 5 points!

# %% [markdown]
# 5-13. Your Ideas: At this point, you’re a more capable programmer than you
# were when you started this book. Now that you have a better sense of how
# real-world situations are modeled in programs, you might be thinking of some
# problems you could solve with your own programs. Record any new ideas you
# have about problems you might want to solve as your programming skills continue to improve. Consider games you might want to write, data sets you might
# want to explore, and web applications you’d like to create

# %%
ideas = ["1. Personal Expense Tracker, program tracks my monthly spending and savings goals.",
    "2. Atlanta Restaurant Recommender , Suggest restaurants based on food type and location.",
    "3. Habit Tracker, Help me build consistent habits like coding, exercising, and reading."]

for idea in ideas:
    print(idea)
# Out:
# 1. Personal Expense Tracker, program tracks my monthly spending and savings goals.
# 2. Atlanta Restaurant Recommender , Suggest restaurants based on food type and location.
# 3. Habit Tracker, Help me build consistent habits like coding, exercising, and reading.
